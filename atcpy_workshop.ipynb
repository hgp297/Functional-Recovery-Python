# %% [markdown]
# # Temp runner

# %%
import driver_PBEE_recovery
import importlib
importlib.reload(driver_PBEE_recovery)
from driver_PBEE_recovery import run_analysis

# %% [markdown]
# ## 4 story Haselton

# %%
model_name = 'haseltonRCMF_4story'

run_analysis(model_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 model_name = 'haseltonRCMF_4story'
# ----> 3 run_analysis(model_name)
#
# File c:\Users\hpham09\OneDrive - UBC\Documents\ubc_postdoc\codebase\Functional-Recovery-Python\driver_PBEE_recovery.py:88, in run_analysis(model_name)
#      85 ## 5. Run Recovery Method
#      86 from main_PBEE_recovery import main_PBEE_recovery
# ---> 88 functionality, damage_consequences = main_PBEE_recovery(damage,
#      89                                                         damage_consequences,
#      90                                                         building_model,
#      91                                                         tenant_units,
#      92                                                         systems,
#      93                                                         subsystems,
#      94                                                         tmp_repair_class,
#      95                                                         impedance_options,
#      96                                                         impeding_factor_medians,
#      97                                                         repair_time_options,
#      98                                                         functionality,
#      99                                                         functionality_options)
#     101 # 6. Save Outputs
#     102 # # Define Output path
#     103 if os.path.exists(os.path.join(os.path.dirname(__file__),'outputs')) == False:
#
# File c:\Users\hpham09\OneDrive - UBC\Documents\ubc_postdoc\codebase\Functional-Recovery-Python\main_PBEE_recovery.py:91, in main_PBEE_recovery(damage, damage_consequences, building_model, tenant_units, systems, subsystems, tmp_repair_class, impedance_options, impeding_factor_medians, repair_time_options, functionality, functionality_options)
#      81 functionality['impeding_factors'] = main_impedance_function.main_impeding_factors(damage, impedance_options,
#      82                                       damage_consequences['repair_cost_ratio_total'],
#      83                                       damage_consequences['repair_cost_ratio_engineering'],
#    (...)
#      87                                       impeding_factor_medians,
#      88                                       functionality_options['include_flooding_impact'])
#      90 ## Construct the Building Repair Schedule
# ---> 91 damage, functionality['worker_data'], functionality['building_repair_schedule'] = main_repair_schedule.main_repair_schedule(damage, building_model, damage_consequences['red_tag'],
#      92     repair_time_options, systems, tmp_repair_class, functionality['impeding_factors'],
#      93     damage_consequences['simulated_replacement_time'])
#      95 ## Calculate the Recovery of Building Reoccupancy and Function
#      96 functionality['recovery'] = main_functionality_function.main_functionality(damage, building_model,
#      97                             damage_consequences, functionality['utilities'],
#      98                             functionality_options, tenant_units, subsystems,
#      99                             functionality['impeding_factors']['temp_repair'])
#
# File c:\Users\hpham09\OneDrive - UBC\Documents\ubc_postdoc\codebase\Functional-Recovery-Python\repair_schedule\main_repair_schedule.py:121, in main_repair_schedule(damage, building_model, simulated_red_tags, repair_time_options, systems, tmp_repair_class, impeding_factors, simulated_replacement_time)
#     119 # Full Repairs
#     120 repair_type = 'full'
# --> 121 full_damage, worker_data = fn_schedule_repairs(damage, repair_type, systems,
#     122                                           max_workers_per_building,
#     123                                           max_workers_per_story,
#     124                                           impeding_factors,
#     125                                           simulated_red_tags,
#     126                                           tmp_repair_complete_day)
#     129 ## Combine temp and full repair schedules
#     130 for tu in range(len(full_damage)):
#
# File c:\Users\hpham09\OneDrive - UBC\Documents\ubc_postdoc\codebase\Functional-Recovery-Python\repair_schedule\main_repair_schedule.py:75, in main_repair_schedule.<locals>.fn_schedule_repairs(damage, repair_type, systems, max_workers_per_building, max_workers_per_story, impeding_factors, simulated_red_tags, tmp_repair_complete_day)
#      72 system_schedule = other_repair_schedule_functions.fn_calc_system_repair_time(damage, repair_type, systems, max_workers_per_building, max_workers_per_story)
#      74 ## Step 2 - Set system repair priority
# ---> 75 sys_idx_priority_matrix = other_repair_schedule_functions.fn_prioritize_systems( systems, repair_type, damage, tmp_repair_complete_day, impeding_factors)
#      77 ## Step 3 - Define system repair constraints
#      78 sys_constraint_matrix= other_repair_schedule_functions.fn_set_repair_constraints( systems, repair_type, simulated_red_tags)
#
# File c:\Users\hpham09\OneDrive - UBC\Documents\ubc_postdoc\codebase\Functional-Recovery-Python\repair_schedule\other_repair_schedule_functions.py:372, in fn_prioritize_systems(systems, repair_type, damage, tmp_repair_complete_day, impeding_factors)
#     370 sys_affects_reoccupancy[:,syst] = np.any(affects_reoccupancy[:,sys_filter], axis = 1); # any damage that potentially affects function in this system
#     371 sys_affects_function[:,syst] = np.any(affects_function[:,sys_filter], axis = 1); # any damage that potentially affects function in this system
# --> 372 if tmp_repair_complete_day != []: # Only if temp repair data is passed in
#     373     all_sys_tmp_repaired = np.all(np.logical_or(tmp_repair_complete_day[:,sys_filter] < np.inf, np.isnan(tmp_repair_complete_day[:,sys_filter])), axis=1) # is every single damaged component resolved by temp repairs
#     374     tmp_repair_quick = np.nanmax(tmp_repair_complete_day[:,sys_filter], axis=1) < impeding_factors['time_sys'][:,syst] # Are the temp repairs for this system resolved before impeding factors are complete
#
# ValueError: operands could not be broadcast together with shapes (700,92) (0,)
