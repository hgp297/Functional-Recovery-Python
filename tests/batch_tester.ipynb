# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# For any model / IM:
#
# 1) Run python 20x
# 2) Run Matlab, or get the results (per IM?)
# 3) Use `evaluate_tolerances` to check

# %% [markdown]
# Successful test suites:
#
# - `2010_PC1a_1`
# - `2010_S3b_4`
# - `2022_C1a_5`
# - `2022_PC1a_1`
#
# Canonical test suite:
# - `ICSB`
# - `RCSW_1story`
# - `haseltonRCMF_12story`
# - `haseltonRCMF_4story`

# %%
from pathlib import Path
from test_utils import batch_run_folder
input_path_to_test = Path('./canonical_suite/haseltonRCMF_4story/')
batch_run_folder(input_path_to_test, n_iter=20)

input_path_to_test = Path('./canonical_suite/haseltonRCMF_12story/')
batch_run_folder(input_path_to_test, n_iter=20)

input_path_to_test = Path('./canonical_suite/ICSB/')
batch_run_folder(input_path_to_test, n_iter=20)

input_path_to_test = Path('./canonical_suite/RCSW_1story/')
batch_run_folder(input_path_to_test, n_iter=20)
# Out:
# Running canonical_suite\ICSB
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.72s
# Recovery assessment complete
# time to run 4.72s
# Recovery assessment complete
# time to run 4.51s
# Recovery assessment complete
# time to run 4.24s
# Recovery assessment complete
# time to run 4.12s
# Recovery assessment complete
# time to run 4.18s
# Recovery assessment complete
# time to run 4.11s
# Recovery assessment complete
# time to run 4.08s
# Recovery assessment complete
# time to run 4.08s
# Recovery assessment complete
# time to run 4.2s
# Recovery assessment complete
# time to run 4.08s
# Recovery assessment complete
# time to run 4.15s
# Recovery assessment complete
# time to run 4.17s
# Recovery assessment complete
# time to run 4.21s
# Recovery assessment complete
# time to run 4.17s
# Recovery assessment complete
# time to run 4.18s
# Recovery assessment complete
# time to run 4.17s
# Recovery assessment complete
# time to run 4.21s
# Recovery assessment complete
# time to run 4.19s
# Recovery assessment complete
# time to run 4.15s
# Running canonical_suite\RCSW_1story
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 1.36s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.49s
# Recovery assessment complete
# time to run 0.44s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.49s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.48s
# Recovery assessment complete
# time to run 0.44s
# Recovery assessment complete
# time to run 0.43s
# Recovery assessment complete
# time to run 0.49s
# Recovery assessment complete
# time to run 0.44s
# Recovery assessment complete
# time to run 0.44s
# Recovery assessment complete
# time to run 0.47s
# Recovery assessment complete
# time to run 0.44s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.45s
# Recovery assessment complete
# time to run 0.48s

# %%
from pathlib import Path
from test_utils import batch_run_folder
input_path_to_test = Path('./extended_suite/2010_PC1a_1/')
batch_run_folder(input_path_to_test, n_iter=20)

input_path_to_test = Path('./extended_suite/2010_S3b_4/')
batch_run_folder(input_path_to_test, n_iter=20)

input_path_to_test = Path('./extended_suite/2022_C1a_5/')
batch_run_folder(input_path_to_test, n_iter=20)

input_path_to_test = Path('./extended_suite/2022_PC1a_1/')
batch_run_folder(input_path_to_test, n_iter=20)
# Out:
# Running extended_suite\2010_PC1a_1\IM_1
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 5.84s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 5.92s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.75s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.57s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.45s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.57s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.49s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.52s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.52s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.64s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.54s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.67s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.57s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.52s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.62s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.7s
# Running extended_suite\2010_PC1a_1\IM_2
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.69s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.98s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.03s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.65s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.35s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.23s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.11s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.1s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.08s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.53s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.91s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.75s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.23s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.15s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.18s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.08s
# Running extended_suite\2010_PC1a_1\IM_3
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.32s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.72s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.67s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.81s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.76s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.77s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.02s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.93s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.07s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.31s
# Running extended_suite\2010_PC1a_1\IM_4
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.0s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.03s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.01s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.01s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.04s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.31s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.04s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.03s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.25s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.2s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.18s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.07s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.08s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.6s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.55s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.2s
# Running extended_suite\2010_PC1a_1\IM_5
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.25s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.4s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.18s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.22s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.07s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.17s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.28s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.34s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.67s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.11s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.19s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.97s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.01s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.98s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.97s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.67s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.59s
# Running extended_suite\2010_PC1a_1\IM_6
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.75s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.53s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.66s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.73s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.56s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.56s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.55s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.92s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.64s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.6s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.75s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.66s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.87s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.88s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.78s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.82s
# Running extended_suite\2010_PC1a_1\IM_7
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.86s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.73s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.87s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.86s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.72s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.58s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.54s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.58s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.7s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.82s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.56s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.44s
# Running extended_suite\2010_S3b_4\IM_1
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 35.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 33.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.49s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.62s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.07s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.13s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.29s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 38.74s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.04s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.77s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.15s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.95s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.04s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.71s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 35.64s
# Running extended_suite\2010_S3b_4\IM_2
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.54s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.57s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.82s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.82s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.67s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.72s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.49s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.32s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.74s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.2s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.22s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.1s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.1s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 35.5s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 35.49s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.25s
# Running extended_suite\2010_S3b_4\IM_3
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.94s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.91s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.31s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.72s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.87s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.08s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.13s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.71s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 35.71s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.16s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.6s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.45s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.65s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.94s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.31s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 48.4s
# Running extended_suite\2010_S3b_4\IM_4
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 48.68s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 50.4s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 49.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 48.8s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.22s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.23s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.49s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.74s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.92s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.21s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.25s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.81s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.88s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 38.21s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.0s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.31s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 38.37s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.21s
# Running extended_suite\2010_S3b_4\IM_5
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.58s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.19s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.45s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.99s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.65s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.42s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.87s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.76s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.02s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 38.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.53s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.03s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 36.63s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 37.1s
# Running extended_suite\2022_C1a_5\IM_1
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.28s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.6s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.87s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.98s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.66s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.77s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.82s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.03s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.81s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.74s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.6s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.31s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.23s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.96s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.22s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.56s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.97s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.93s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 39.94s
# Running extended_suite\2022_C1a_5\IM_2
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.24s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.3s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.91s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.28s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.62s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.89s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.71s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.34s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.02s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.79s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.68s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 40.83s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.39s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.24s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.64s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.25s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 41.62s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.6s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.06s
# Running extended_suite\2022_C1a_5\IM_3
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.26s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.7s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.88s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 42.63s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.89s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.93s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.77s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.27s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.2s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.97s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.99s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.75s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.27s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.0s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 43.53s
# Running extended_suite\2022_C1a_5\IM_4
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.98s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.08s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.3s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.36s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.2s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.86s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.71s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.96s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.64s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 44.78s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.63s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.02s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.35s
# Running extended_suite\2022_C1a_5\IM_5
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.98s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.46s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.29s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.95s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.05s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.77s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.85s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.9s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.81s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 45.97s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.11s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.7s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.11s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.19s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.21s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 49.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 47.75s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 46.88s
# Running extended_suite\2022_PC1a_1\IM_1
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.15s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.1s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.15s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.15s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 5.99s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.01s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.16s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.11s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.18s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.12s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.05s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.12s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.17s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.11s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.05s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.06s
# Running extended_suite\2022_PC1a_1\IM_2
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.52s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.41s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.4s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.44s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.4s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.31s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.37s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.32s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.37s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.33s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.23s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.57s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.42s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.37s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.35s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.27s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.36s
# Running extended_suite\2022_PC1a_1\IM_3
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.49s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.36s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.57s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.53s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.52s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.55s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.58s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.53s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.61s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.52s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.51s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 6.55s
# Running extended_suite\2022_PC1a_1\IM_4
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.18s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.17s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.15s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.01s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.0s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.02s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.8s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.89s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.87s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.47s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.5s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.16s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.89s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.06s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.09s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.14s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.08s
# Running extended_suite\2022_PC1a_1\IM_5
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.32s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.29s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.36s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.34s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.39s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.29s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.37s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.38s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.59s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.43s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.54s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.48s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.66s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.35s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.23s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.29s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.22s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 8.24s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.62s
# Building simulated_inputs.json from raw inputs...
# Recovery assessment complete
# time to run 7.52s

# %% [markdown]
# After batch running, use `compare_runs` to test against matlab outputs.
